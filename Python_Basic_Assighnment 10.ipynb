# %% [markdown]
# 1.How do you distinguish between shutil.copy() and shutil.copytree()?
#
# Answer :
#
#     shutil.copy() will copy the file at the path source to the folder at the path destination.
#     shutil.copy() will copy a single file while shutil.copytree() will copy an entire folder and every
#     folder contained.
#
#
# 2.What function is used to rename files?
#
# Answer :
#
#   Os module in python provies functions to interact with the operating system.Os comes under python
#   standard utilities.
#   os.rename() method in python is used to rename a file or directory.

# %% [markdown]
# 3.What is the difference between the delete functions in the send2trash and shutil modules?
#
# Answer :
#
#     Shutil module provides a funciton called as shutil.rmtree() which deletes a directory and all its
#     contents. The other functions with similar functionality are os.remove() removes a file,                               os.rmdir() removes
#     a empty  directory. The problem with these functions is once a file is deleted. it will be lost
#     permanently, if a file is deleted accidentally using these methods there is no way we can recover the
#     deleted  file.
#
#    Where as send2trash module provides a function called send2trash.send2trash() to delete a file/directory.
#    These methods moves the files/directories to trash folder instead of permanently deleting them. hence if
#    a  file/folder is deleted accidentally it can be still recovered from trash folder, if is deleted using
#    the send2trash.send2trash() function. send2trash is not included with python standard libary like os &
#    shutil modules. it needs to be installed explicitly using the command !pip install send2trash.
#
# 4.ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?
#
# Answer :
#
#     The zipfile.ZipFile() function is equivalent to the open() function; the first argument is the filename,
#     and  the second argument is the mode to open the ZIP file in (read, write, or append).

# %% [markdown]
# 5.Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder

# %%
import os, shutil

def search_and_copy(folder, extensions, destFolder):
    folder = os.path.abspath(folder)
    destFolder = os.path.abspath(destFolder)
    print('searching --> {} for {} file'.format(folder,extensions))
    for foldername, subfolders, filenames in os.walk(folder):
        for filename in filenames:
            name, extension = os.path.splitext(filename)
            if extension in extensions:
                fileAbsPath = foldername + os.path.sep + filename
                print('Coping', fileAbsPath, 'to', destFolder)
                shutil.copy(fileAbsPath, destFolder)

extensions = ['.pdf']
folder = 'C:\\Users\B.Sreenath Reddy'
destFolder = 'destination'
search_and_copy(folder, extensions, destFolder)
# Out:
# searching --> C:\Users\B.Sreenath Reddy for ['.pdf'] file
# Coping C:\Users\B.Sreenath Reddy\anaconda3\envs\Internship_ineuron\Lib\site-packages\matplotlib\mpl-data\images\back.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\envs\Internship_ineuron\Lib\site-packages\matplotlib\mpl-data\images\filesave.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\envs\Internship_ineuron\Lib\site-packages\matplotlib\mpl-data\images\forward.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\envs\Internship_ineuron\Lib\site-packages\matplotlib\mpl-data\images\hand.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\envs\Internship_ineuron\Lib\site-packages\matplotlib\mpl-data\images\help.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\envs\Internship_ineuron\Lib\site-packages\matplotlib\mpl-data\images\home.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\envs\Internship_ineuron\Lib\site-packages\matplotlib\mpl-data\images\matplotlib.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\envs\Internship_ineuron\Lib\site-packages\matplotlib\mpl-data\images\move.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\envs\Internship_ineuron\Lib\site-packages\matplotlib\mpl-data\images\qt4_editor_options.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\envs\Internship_ineuron\Lib\site-packages\matplotlib\mpl-data\images\subplots.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\envs\Internship_ineuron\Lib\site-packages\matplotlib\mpl-data\images\zoom_to_rect.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\envs\pythonProject3\Lib\site-packages\matplotlib\mpl-data\images\back.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\envs
3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_read.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_read_add_passphrase.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_read_data.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_read_disk.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_read_extract.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_read_filter.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_read_format.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_read_free.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_read_header.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_read_new.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_read_open.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_read_set_options.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_util.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_write.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_write_blocksize.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_write_data.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_write_disk.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_write_filter.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_write_finish_entry.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_write_format.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_write_free.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_write_header.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_write_new.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_write_open.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_write_set_options.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\archive_write_set_passphrase.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\bsdcpio.1.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\bsdtar.1.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\cpio.5.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\libarchive-formats.5.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\libarchive.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\libarchive_changes.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\libarchive_internals.3.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\mtree.5.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\libarchive-3.4.2-h5e25573_0\Library\share\man\pdf\tar.5.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\matplotlib-base-3.5.1-py39hd77b12b_1\Lib\site-packages\matplotlib\mpl-data\images\back.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\matplotlib-base-3.5.1-py39hd77b12b_1\Lib\site-packages\matplotlib\mpl-data\images\filesave.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\matplotlib-base-3.5.1-py39hd77b12b_1\Lib\site-packages\matplotlib\mpl-data\images\forward.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\matplotlib-base-3.5.1-py39hd77b12b_1\Lib\site-packages\matplotlib\mpl-data\images\hand.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\matplotlib-base-3.5.1-py39hd77b12b_1\Lib\site-packages\matplotlib\mpl-data\images\help.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\matplotlib-base-3.5.1-py39hd77b12b_1\Lib\site-packages\matplotlib\mpl-data\images\home.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\matplotlib-base-3.5.1-py39hd77b12b_1\Lib\site-packages\matplotlib\mpl-data\images\matplotlib.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\matplotlib-base-3.5.1-py39hd77b12b_1\Lib\site-packages\matplotlib\mpl-data\images\move.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\matplotlib-base-3.5.1-py39hd77b12b_1\Lib\site-packages\matplotlib\mpl-data\images\qt4_editor_options.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\matplotlib-base-3.5.1-py39hd77b12b_1\Lib\site-packages\matplotlib\mpl-data\images\subplots.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\anaconda3\pkgs\matplotlib-base-3.5.1-py39hd77b12b_1\Lib\site-packages\matplotlib\mpl-data\images\zoom_to_rect.pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\AppData\Local\Packages\microsoft.windowscommunicationsapps_8wekyb3d8bbwe\LocalState\Files\S0\5\Attachments\8111202205080702933233[218].pdf to C:\Users\B.Sreenath Reddy\destination
# Coping C:\Users\B.Sreenath Reddy\AppData\Local\Packages\microsoft.windowscommunicationsapps_8wekyb3d8bbwe\LocalState\Files\S0\5\Attachments\8111202206097800443233[227].pdf to C:\Users\B.Sreenath Reddy\destination
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [2], in <cell line: 18>()
#      16 folder = 'C:\\Users\B.Sreenath Reddy'
#      17 destFolder = 'destination'
# ---> 18 search_and_copy(folder, extensions, destFolder)
#
# Input In [2], in search_and_copy(folder, extensions, destFolder)
#      11 fileAbsPath = foldername + os.path.sep + filename
#      12 print('Coping', fileAbsPath, 'to', destFolder)
# ---> 13 shutil.copy(fileAbsPath, destFolder)
#
# File ~\anaconda3\lib\shutil.py:427, in copy(src, dst, follow_symlinks)
#     425 if os.path.isdir(dst):
#     426     dst = os.path.join(dst, os.path.basename(src))
# --> 427 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     428 copymode(src, dst, follow_symlinks=follow_symlinks)
#     429 return dst
#
# File ~\anaconda3\lib\shutil.py:266, in copyfile(src, dst, follow_symlinks)
#     264 with open(src, 'rb') as fsrc:
#     265     try:
# --> 266         with open(dst, 'wb') as fdst:
#     267             # macOS
#     268             if _HAS_FCOPYFILE:
#     269                 try:
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\B.Sreenath Reddy\\destination'
