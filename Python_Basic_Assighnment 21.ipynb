# %% [markdown]
# 1.Add the current date to the text file today.txt as a string.

# %%
import datetime
file = open('today.txt','w')
file.write(datetime.datetime.now().strftime("%d-%m-%Y"))
file.close()
file = open('today.txt','r')
print(file.read())
file.close()
# Out:
# 15-08-2022

# %% [markdown]
# 2.Read the text file today.txt into the string today_string

# %%
file = open('today.txt','r')
today_string = file.read()
print(today_string)
# Out:
# 15-08-2022

# %% [markdown]
# 3.Parse the date from today_string.

# %%
from datetime import datetime
parsed_data = datetime.strptime(today_string, '%d-%m-%Y')
print(parsed_data)
# Out:
# 2022-08-15 00:00:00

# %% [markdown]
# 4.List the files in your current directory

# %%
import os
os.chdir("C:\\Users\B.Sreenath Reddy\PycharmProjects")
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# sreenath.zip
# Credit Card DPR.docx
# Credit Card HLD.docx
# finalized_mode4.sav
# finalized_model.sav
# finalized_model1.sav
# LOW LEVEL DESIGN Credit Card.docx
# main.py
# Procfile
# Project Architeture Credit Card.docx
# requirements.txt
# Wire frame credit card.docx
# COMMIT_EDITMSG
# config
# description
# FETCH_HEAD
# HEAD
# index
# ORIG_HEAD
# applypatch-msg.sample
# commit-msg.sample
# fsmonitor-watchman.sample
# post-update.sample
# pre-applypatch.sample
# pre-commit.sample
# pre-merge-commit.sample
# pre-push.sample
# pre-rebase.sample
# pre-receive.sample
# prepare-commit-msg.sample
# push-to-checkout.sample
# update.sample
# exclude
# HEAD
# main
# main1
# main
# main1
# b529b07f34547e29ebd2c6b57d2090330b4ff3
# 636031523c83b0af0ba80978df71ab94a6c493
# b85aa708b8ac8592d00c58eeea20232fdf26ec
# 974d0dc4f58a207a66326e51fe5d27eec22016
# 5ce2da2d6447d11dfe32bfb846c3d5b199fc99
# 65d98a79c5b6e385b0f8acacca193b878626e2
# f82e3764fedd8556370f53aa78bce556b06133
# ...

# %% [markdown]
# 5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %%
import os
os.chdir("D:\\Datasets")
for folders, subfolders, files in os.walk(os.getcwd()):
    for file in files:
        print(file)
# Out:
# adult.csv
# adult.html
# Advertising.csv
# credit card Profile Report.html
# lr_reg.sav
# test.html
# UCI_Credit_Card.csv
# catboost_training.json
# learn_error.tsv
# test_error.tsv
# time_left.tsv
# events.out.tfevents
# events.out.tfevents

# %% [markdown]
# 6.Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
pip install zoo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import multiprocessing,time,datetime
import zoo
start = time.time()
process1 = zoo.process1()
process2 = zoo.process1()
process3 = zoo.process1()

print(datetime.datetime.now())
if __name__=="__main__":



    p1 = multiprocessing.Process(target=process1)
    p2 = multiprocessing.Process(target=process2)
    p3 = multiprocessing.Process(target=process3)

    p1.start()
    p2.start()
    p3.start()

    p1.join()
    p2.join()
    p3.join()

end = time.time()


print("It takes " +str(end-start)+" seconds")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 import multiprocessing,time,datetime
# ----> 2 import zoo
#       3 start = time.time()
#       4 process1 = zoo.process1()
#
# ModuleNotFoundError: No module named 'zoo'

# %% [markdown]
# 7.Create a date object of your day of birth.

# %%
from datetime import datetime
my_dob = datetime.strptime('18/03/2001','%d/%m/%Y')
print(my_dob, type(my_dob))
# Out:
# 2001-03-18 00:00:00 <class 'datetime.datetime'>

# %% [markdown]
# 8.What day of the week was your day of birth?

# %%
from datetime import datetime
my_dob = datetime(2001,3,18)
my_dob.strftime("%A")
# Out:
# 'Sunday'

# %% [markdown]
# 9.When will you be (or when were you) 10,000 days old?

# %%
from datetime import datetime, timedelta
my_dob = datetime.strptime("18/03/2001",'%d/%m/%Y')
future_date = my_dob-timedelta(10000)
future_date
# Out:
# datetime.datetime(1973, 10, 31, 0, 0)
